# %%
# This file uses sentences from ClaimsExtractedByUs to learn the sentence-look_up_value distribution
# considering unique (sentence, claim) pairs

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import LinearSVC
from sklearn.calibration import CalibratedClassifierCV
from sklearn.pipeline import FeatureUnion
import numpy as np

# %%
path = "data/annotated_11_19_2019/ClaimsExtractedByUs.csv"

# %%
df = pd.read_csv(path, encoding="latin1")

# %%
df
# Out:
#                                                    Text  \
# 0     The Sustainable Development Scenario starts wi...
# 1     The Sustainable Development Scenario starts wi...
# 2     The Sustainable Development Scenario starts wi...
# 3     For the first time the number of people withou...
# 4     For the first time the number of people withou...
# 5     For the first time the number of people withou...
# 6     Despite significant steps forward in Kenya, Et...
# 7                            Total electrification rate
# 8                            Total electrification rate
# 9                            Total electrification rate
# 10                           Total electrification rate
# 11    Today energy-related outdoor air pollution lea...
# 12    Today energy-related outdoor air pollution lea...
# 13    Significant new policies have been announced t...
# 14    Energy-related carbon dioxide (CO2) emissions ...
# 15    Energy-related carbon dioxide (CO2) emissions ...
# 16    Energy-related carbon dioxide (CO2) emissions ...
# 17    Energy-related carbon dioxide (CO2) emissions ...
# 18    Energy-related carbon dioxide (CO2) emissions ...
# 19    Energy-related carbon dioxide (CO2) emissions ...
# 20    650 million people will still lack electricity...
# 21    650 million people will still lack electricity...
# 22    650 million people will still lack electricity...
# 23    Lower levels of air pollutants will be insuffi...
# 24    And CO2 emissions are set to rise gradually to...
# 25    premature deaths from outdoor air pollution ar...
# 26    And CO2 levels decline rapidly in line with th...
# 27    And a move away from traditional use of biomas...
# 28    And a move away from traditional use of biomas...
# 29                                 HAP premature deaths
# ...                                                 ...
# 1776  If waste from all those who lack access to saf...
# 1777  If current consumption patterns persist, globa...
# 1778  The energy sectoräó»s share of total global wa...
# 1779  The energy sectoräó»s share of total global wa...
# 1780  The energy sectoräó»s share of total global wa...
# 1781  The energy sectoräó»s share of total global wa...
# 1782  In a  scenario water withdrawals by the energy...
# 1783  In a decarbonisation scenario water withdrawal...
# 1784                                              #REF!
# 1785  Shifting the emphasis away from an approach fo...
# 1786  Shifting the emphasis away from an approach fo...
# 1787  However, the higher level of consumption (+10%...
# 1788  In 2016 the energy sector withdrew around 340 ...
# 1789  In 2016 the energy sector withdrew around 360 ...
# 1790  The power sector is responsible for the majori...
# 1791  The power sector is responsible for the majori...
# 1792  Primary energy production is responsible  for ...
# 1793  Primary energy production is responsible  for ...
# 1794  Primary energy production is responsible  for ...
# 1795  In the Sustainable Development Scenario, globa...
# 1796  In the Sustainable Development Scenario, globa...
# 1797  In the Sustainable Development Scenario, globa...
# 1798  In the Sustainable Development Scenario, globa...
# 1799  Increased energy efficiency, the move away fro...
# 1800  Increased energy efficiency, the move away fro...
# 1801  This helps with progress towards SDG Target 6....
# 1802  This helps with progress towards SDG Target 6....
# 1803  Ensuring 2.1 billion people  have access to cl...
# 1804  Ensuring 2.1 billion people  have access to cl...
# 1805  Ensuring 2.1 billion people  have access to cl...
#
#                                         Published value  \
# 0                                                     7
# 1                                                   3.9
# 2                                                    13
# 3                                    For the first time
# 4                                  fell below 1 billion
# 5                                is declining gradually
# 6                                              Ethiopia
# 7                                              Tanzania
# 8                                               Nigeria
# 9                                           600 million
# 10                                          2.7 billion
# 11                                          2.9 million
# 12                                          2.6 million
# 13                                           three-year
# 14                                        increased CO2
# 15                                      economic growth
# 16                               slowdown in efficiency
# 17                                 increased deployment
# 18                                 increased deployment
# 19                                 increased deployment
# 20                                          650 million
# 21                                           almost all
# 22                                          > 2 billion
# 23                                   4 million annually
# 24                                              35.8 Gt
# 25                                       half a million
# 26                                      decline rapidly
# 27                                          reduces GHG
# 28                 reducing premature deaths linked äó_
# 29                                               by 70%
# ...                                                 ...
# 1776                                                180
# 1777                                                0.4
# 1778                                       roughly 10%
# 1779                                       roughly 10%
# 1780                                               0.03
# 1781                                             rising
# 1782  withdrawals by the energy sector in 2030 rise ...
# 1783                                     around 10 bcm
# 1784                                              #REF!
# 1785                           lower water withdrawals
# 1786                                             (-20%)
# 1787                                             "+10%"
# 1788                                            340 bcm
# 1789                                             50 bcm
# 1790                                       majority of
# 1791                                   over one-thirds
# 1792                    two-thirds of water consumption
# 1793                                         almost 40%
# 1794                                                0.3
# 1795                                           decline
# 1796                                            275 bcm
# 1797                                         rises 50%
# 1798                                             75 bcm
# 1799                    overall lower water withdrawals
# 1800        increase in both withdrawal and consumption
# 1801                                                0.5
# 1802                                               0.25
# 1803          adds less than 1% to global energy demand
# 1804          adds less than 1% to global energy demand
# 1805                                       w e recovery
#
#                                       Author calc Value Look-up value  \
# 0                                                   7.1           NaN
# 1                                                   3.9           NaN
# 2                                                    13           NaN
# 3                                                  TRUE           NaN
# 4                                                  TRUE           NaN
# 5                                                  TRUE           NaN
# 6                                                0.4014           NaN
# 7                                                 0.223      Ethiopia
# 8                                           0.197945098      Tanzania
# 9                                                  TRUE       Nigeria
# 10                                          2.655652285       Nigeria
# 11                                          2.932324966           NaN
# 12                                                 TRUE           NaN
# 13    2018-2020 Three-year Action Plan for Winning t...           NaN
# 14                                                 TRUE           NaN
# 15                                                 TRUE           NaN
# 16                                                 TRUE           NaN
# 17                                                 TRUE           NaN
# 18                                           723.284262     PGINrenew
# 19                                          770.4351901         #REF!
# 20                                            649.19667           NaN
# 21                                          0.894448242           NaN
# 22                                          2.187896624           NaN
# 23                                           4.04049615           NaN
# 24                                          35881.34505           NaN
# 25                                         -0.537634232           NaN
# 26                                         -0.458357433           NaN
# 27                                         -18.52023579           NaN
# 28                                      almost entirely           NaN
# 29                                         -0.697134402         Total
# ...                                                 ...           ...
# 1776                                        180.7163668           NaN
# 1777  http://www.parlamericas.org/uploads/documents/...           NaN
# 1778                                        0.096150542           NaN
# 1779                                        0.029916503           NaN
# 1780                                        0.032180667           NaN
# 1781                                               TRUE           NaN
# 1782                                        0.041658311           NaN
# 1783                                        10.67998972           NaN
# 1784                                        0.162534772           NaN
# 1785                                               TRUE           NaN
# 1786                                       -0.181736484           NaN
# 1787                                        0.095895943           NaN
# 1788                                        337.5509675           NaN
# 1789                                        47.28044161           NaN
# 1790                                        0.844966977           NaN
# 1791                                        0.373224254           NaN
# 1792                                         0.68603428           NaN
# 1793                                        0.380477771           NaN
# 1794                                        0.305556508           NaN
# 1795                                               TRUE           NaN
# 1796                                           272.4427           NaN
# 1797                                        0.523043628           NaN
# 1798                                        72.01017534           NaN
# 1799                                                 ok           NaN
# 1800                                                 ok           NaN
# 1801                                       -0.484183913           NaN
# 1802                                       -0.248476696           NaN
# 1803                                               TRUE           NaN
# 1804                                        0.004115597           NaN
# 1805                                        0.002933371           NaN
#
#      Look-up year  Scenario                                     Fixed_Formulas
# 0             NaN       NaN  'C:\Users\Mohammed Saeed\Desktop\Energy Fact C...
# 1             NaN       NaN  'C:\Users\Mohammed Saeed\Desktop\Energy Fact C...
# 2             NaN       NaN  'C:\Users\Mohammed Saeed\Desktop\Energy Fact C...
# 3             NaN       NaN  'C:\Users\Mohammed Saeed\Desktop\Energy Fact C...
# 4             NaN       NaN  'C:\Users\Mohammed Saeed\Desktop\Energy Fact C...
# 5             NaN       NaN  'C:\Users\Mohammed Saeed\Desktop\Energy Fact C...
# 6             NaN       NaN                                            G29-G28
# 7            2017  Historic                                            G32-G31
# 8            2017  Historic                                            G35-G34
# 9            2017  Historic  'C:\Users\Mohammed Saeed\Desktop\Energy Fact C...
# 10           2017  Historic  'C:\Users\Mohammed Saeed\Desktop\Energy Fact C...
# 11            NaN       NaN  'C:\Users\Mohammed Saeed\Desktop\Energy Fact C...
# 12            NaN       NaN  'C:\Users\Mohammed Saeed\Desktop\Energy Fact C...
# 13            NaN       NaN  'C:\Users\Mohammed Saeed\Desktop\Energy Fact C...
# 14            NaN       NaN  'C:\Users\Mohammed Saeed\Desktop\Energy Fact C...
# 15            NaN       NaN  'C:\Users\Mohammed Saeed\Desktop\Energy Fact C...
# 16            NaN       NaN  'C:\Users\Mohammed Saeed\Desktop\Energy Fact C...
# 17            NaN       NaN                                            G55>G54
# 18           2016  Historic  VLOOKUP($A54,G:\EO2018\FrozenResults\Demand\_A...
# 19        #VALUE!  Historic  VLOOKUP($A55,G:\EO2018\FrozenResults\Demand\_A...
# 20            NaN       NaN  'C:\Users\Mohammed Saeed\Desktop\Energy Fact C...
# 21            NaN       NaN  'C:\Users\Mohammed Saeed\Desktop\Energy Fact C...
# 22            NaN       NaN  'C:\Users\Mohammed Saeed\Desktop\Energy Fact C...
# 23            NaN       NaN  'C:\Users\Mohammed Saeed\Desktop\Energy Fact C...
# 24            NaN       NaN  'C:\Users\Mohammed Saeed\Desktop\Energy Fact C...
# 25            NaN       NaN  'C:\Users\Mohammed Saeed\Desktop\Energy Fact C...
# 26            NaN       NaN  'C:\Users\Mohammed Saeed\Desktop\Energy Fact C...
# 27            NaN       NaN  'C:\Users\Mohammed Saeed\Desktop\Energy Fact C...
# 28            NaN       NaN  'C:\Users\Mohammed Saeed\Desktop\Energy Fact C...
# 29       2040 SDS  Historic                                          G84/G83-1
# ...           ...       ...                                                ...
# 1776          NaN       NaN  'G:\EO2018\Analysis\Water_Energy\Data\Water_en...
# 1777          NaN       NaN  http://www.parlamericas.org/uploads/documents/...
# 1778          NaN       NaN  SUM(G:\EO2018\Analysis\Water_Energy\2018 Model...
# 1779          NaN       NaN  G:\EO2018\Analysis\Water_Energy\2018 Models\Wa...
# 1780          NaN       NaN  SUM(G:\EO2018\Analysis\Water_Energy\2018 Model...
# 1781          NaN       NaN  (G:\EO2018\Analysis\Water_Energy\2018 Models\W...
# 1782          NaN       NaN  F235/'C:\Users\Mohammed Saeed\Desktop\Energy F...
# 1783          NaN       NaN  F237-'C:\Users\Mohammed Saeed\Desktop\Energy F...
# 1784        450 C       NaN                                        F237/F238-1
# 1785          NaN       NaN  'C:\Users\Mohammed Saeed\Desktop\Energy Fact C...
# 1786          NaN       NaN  'C:\Users\Mohammed Saeed\Desktop\Energy Fact C...
# 1787          NaN       NaN  'C:\Users\Mohammed Saeed\Desktop\Energy Fact C...
# 1788          NaN       NaN  'C:\Users\Mohammed Saeed\Desktop\Energy Fact C...
# 1789          NaN       NaN  'C:\Users\Mohammed Saeed\Desktop\Energy Fact C...
# 1790          NaN       NaN                                          C255/G250
# 1791          NaN       NaN                                          C256/G250
# 1792          NaN       NaN  'C:\Users\Mohammed Saeed\Desktop\Energy Fact C...
# 1793          NaN       NaN                                          C262/G252
# 1794          NaN       NaN                                          C263/G252
# 1795          NaN       NaN  'C:\Users\Mohammed Saeed\Desktop\Energy Fact C...
# 1796          NaN       NaN  'C:\Users\Mohammed Saeed\Desktop\Energy Fact C...
# 1797          NaN       NaN  'C:\Users\Mohammed Saeed\Desktop\Energy Fact C...
# 1798          NaN       NaN  'C:\Users\Mohammed Saeed\Desktop\Energy Fact C...
# 1799          NaN       NaN                                                 ok
# 1800          NaN       NaN                                                 ok
# 1801          NaN       NaN  'C:\Users\Mohammed Saeed\Desktop\Energy Fact C...
# 1802          NaN       NaN  'C:\Users\Mohammed Saeed\Desktop\Energy Fact C...
# 1803          NaN       NaN                                            G329<1%
# 1804          6.1         2                                          C331/C336
# 1805    6.2 & 6.3     #REF!                                   (C333+C329)/C336
#
# [1806 rows x 7 columns]

# %%
df_lookup = df[df["Fixed_Formulas"].str.contains("LOOKUP")]

# %%
df_lookup
# Out:
#                                                    Text  \
# 18    Energy-related carbon dioxide (CO2) emissions ...
# 19    Energy-related carbon dioxide (CO2) emissions ...
# 32    Stronger policy action leads to substantially ...
# 33    Stronger policy action leads to substantially ...
# 34    Stronger policy action leads to substantially ...
# 35    Stronger policy action leads to substantially ...
# 36    Stronger policy action leads to substantially ...
# 37    Stronger policy action leads to substantially ...
# 39    Stronger policy action leads to substantially ...
# 40    Stronger policy action leads to substantially ...
# 42    Stronger policy action leads to substantially ...
# 43    Stronger policy action leads to substantially ...
# 53    for the first time the number of people withou...
# 54    for the first time the number of people withou...
# 55    for the first time the number of people withou...
# 56    for the first time the number of people withou...
# 57    for the first time the number of people withou...
# 58    for the first time the number of people withou...
# 59    for the first time the number of people withou...
# 60    for the first time the number of people withou...
# 64    In sub-Saharan Africa 600 million people are s...
# 72    Energy-related carbon dioxide (CO2) emissions ...
# 73    Energy-related carbon dioxide (CO2) emissions ...
# 74    Energy-related carbon dioxide (CO2) emissions ...
# 75    Energy-related carbon dioxide (CO2) emissions ...
# 77    Energy-related carbon dioxide (CO2) emissions ...
# 78    Energy-related carbon dioxide (CO2) emissions ...
# 80    Energy-related carbon dioxide (CO2) emissions ...
# 82                                                    0
# 83                                                    0
# ...                                                 ...
# 1648  The proportion is set to remain almost unchang...
# 1650  In the Sustainable Development Scenario, effor...
# 1651  In the Sustainable Development Scenario, effor...
# 1652  In the Sustainable Development Scenario, effor...
# 1666  In the Sustainable Development Scenario, a com...
# 1667  In the Sustainable Development Scenario, a com...
# 1669  In the Sustainable Development Scenario, a com...
# 1670  In the Sustainable Development Scenario, a com...
# 1671  In the Sustainable Development Scenario, a com...
# 1672  In the Sustainable Development Scenario, a com...
# 1674  In the Sustainable Development Scenario, a com...
# 1675  In the Sustainable Development Scenario, a com...
# 1676  In the Sustainable Development Scenario, a com...
# 1677  In the Sustainable Development Scenario, a com...
# 1679  The share of electricity increases substantial...
# 1680  The share of electricity increases substantial...
# 1681  The share of electricity increases substantial...
# 1682  The share of electricity increases substantial...
# 1684  The share of electricity increases substantial...
# 1685  The share of electricity increases substantial...
# 1686  The share of electricity increases substantial...
# 1687  The share of electricity increases substantial...
# 1689  The share of electricity increases substantial...
# 1690  The share of electricity increases substantial...
# 1691  The share of electricity increases substantial...
# 1692  The share of electricity increases substantial...
# 1694  Support  for renewable electricity has led to ...
# 1695  Support  for renewable electricity has led to ...
# 1750  For example, mini-grids äóñ which provide elec...
# 1751  For example, mini-grids äóñ which provide elec...
#
#                           Published value Author calc Value  \
# 18                   increased deployment        723.284262
# 19                   increased deployment       770.4351901
# 32                   substantially higher       38.27872429
# 33                   substantially higher       309.3837303
# 34                   substantially higher       224.3022014
# 35                   substantially higher       97.30096692
# 36                   substantially higher        338.900707
# 37                   substantially higher       279.5660694
# 39                         stays close to       13971.58601
# 40                         stays close to       13715.01342
# 42                               doubling        127177.761
# 43                               doubling        276075.699
# 53                     for the first time        1422.12966
# 54                     for the first time       1387.485319
# 55                     for the first time         1382.0561
# 56                     for the first time       1323.599636
# 57                     for the first time       1258.392633
# 58                     for the first time        1114.60537
# 59                     for the first time       1091.326985
# 60                     for the first time        992.501348
# 64                     600 million people         580.67282
# 72      for the first time in three years       32138.38726
# 73      for the first time in three years       32080.90364
# 74      for the first time in three years       32053.08108
# 75      for the first time in three years        32580.7653
# 77                        economic growth        122666.148
# 78                        economic growth        127177.761
# 80                slow-down in efficiency       0.117954653
# 82     increased deployment of renewables        723.284262
# 83     increased deployment of renewables       770.4351901
# ...                                   ...               ...
# 1648                     almost unchanged        10920.2774
# 1650             almost total elimination       17110.14893
# 1651             almost total elimination       3241.379034
# 1652             almost total elimination       1001.321093
# 1666                            increased       1846.007222
# 1667                            increased       2801.607155
# 1669                        in particular       364.4402556
# 1670                        in particular       2639.732875
# 1671                        in particular        160.020896
# 1672                        in particular       3616.968509
# 1674                               higher       2801.607155
# 1675                               higher       9957.669459
# 1676                               higher       2984.976102
# 1677                               higher       12581.24994
# 1679   increases substantially - industry       945.1539478
# 1680   increases substantially - industry       3196.620894
# 1681   increases substantially - industry       768.0354706
# 1682   increases substantially - industry       2855.353287
# 1684  increases substantially - buildings        1404.66598
# 1685  increases substantially - buildings       2860.292405
# 1686  increases substantially - buildings         981.52971
# 1687  increases substantially - buildings       3047.478933
# 1689  increases substantially - transport       364.4402556
# 1690  increases substantially - transport       2639.732875
# 1691  increases substantially - transport       32.50198835
# 1692  increases substantially - transport       2794.331545
# 1694                       rapidly rising       144.9949159
# 1695                       rapidly rising       402.1286424
# 1750                                 0.45       406.7814666
# 1751                                 0.45         920.50606
#
#                     Look-up value                       Look-up year  \
# 18                      PGINrenew                               2016
# 19                          #REF!                            #VALUE!
# 32         InvCosts_IND_Eff_Total                            cum2040
# 33         InvCosts_TRA_Eff_Total                            cum2040
# 34        InvCosts_BLDG_Eff_Total                            cum2040
# 35         InvCosts_IND_Eff_Total                            cum2040
# 36         InvCosts_TRA_Eff_Total                            cum2040
# 37        InvCosts_BLDG_Eff_Total                            cum2040
# 39                      TPEDtotal                               2017
# 40                      TPEDtotal                               2040
# 42                            GDP                               2017
# 43                            GDP                               2040
# 53                PopwoElecAccess                               2010
# 54                PopwoElecAccess                            #VALUE!
# 55                PopwoElecAccess                            #VALUE!
# 56                PopwoElecAccess                            #VALUE!
# 57                PopwoElecAccess                            #VALUE!
# 58                PopwoElecAccess                            #VALUE!
# 59                PopwoElecAccess                            #VALUE!
# 60                PopwoElecAccess                            #VALUE!
# 64                PopwoElecAccess                               2030
# 72                   CO2TPEDtotal                               2014
# 73                   CO2TPEDtotal                            #VALUE!
# 74                   CO2TPEDtotal                            #VALUE!
# 75                   CO2TPEDtotal                            #VALUE!
# 77                            GDP                               2016
# 78                          #REF!                            #VALUE!
# 80                     TPEDperGDP                               2014
# 82                      PGINrenew                               2016
# 83                          #REF!                            #VALUE!
# ...                           ...                                ...
# 1648  PM_RESComb_Cookstoves_Total                               2040
# 1650                PM_Bldg_Total                               2015
# 1651                PM_Bldg_Total                               2030
# 1652                PM_Bldg_Total                               2040
# 1666                      TFCelec                               2017
# 1667                      TFCelec                               2040
# 1669                 TOTTRANSelec                               2040
# 1670                TOTTRANStotal                               2040
# 1671                 TOTTRANSelec                               2040
# 1672                TOTTRANStotal                               2040
# 1674                      TFCelec                               2040
# 1675                     TFCtotal                               2040
# 1676                      TFCelec                               2040
# 1677                     TFCtotal                               2040
# 1679                   TOTINDelec                               2040
# 1680                  TOTINDtotal                               2040
# 1681                   TOTINDelec                               2017
# 1682                  TOTINDtotal                               2017
# 1684                BUILDINGSelec                               2040
# 1685               BUILDINGStotal                               2040
# 1686                BUILDINGSelec                               2017
# 1687               BUILDINGStotal                               2017
# 1689                 TOTTRANSelec                               2040
# 1690                TOTTRANStotal                               2040
# 1691                 TOTTRANSelec                               2017
# 1692                TOTTRANStotal                               2017
# 1694      CapAddTotal_WindSolarPV                               2017
# 1695      CapAddTotal_WindSolarPV                               2040
# 1750                          NaN  AccessConnection_rural_total_Mini
# 1751                          NaN       AccessConnection_rural_total
#
#       Scenario                                     Fixed_Formulas
# 18    Historic  VLOOKUP($A54,G:\EO2018\FrozenResults\Demand\_A...
# 19    Historic  VLOOKUP($A55,G:\EO2018\FrozenResults\Demand\_A...
# 32         NaN  VLOOKUP(A94,G:\EO2018\FrozenResults\Investment...
# 33         NaN  VLOOKUP(A95,G:\EO2018\FrozenResults\Investment...
# 34         NaN  VLOOKUP(A96,G:\EO2018\FrozenResults\Investment...
# 35         NaN  VLOOKUP(A97,G:\EO2018\FrozenResults\Investment...
# 36         NaN  VLOOKUP(A98,G:\EO2018\FrozenResults\Investment...
# 37         NaN  VLOOKUP(A99,G:\EO2018\FrozenResults\Investment...
# 39         SDS  VLOOKUP($A101,G:\EO2018\FrozenResults\Demand\_...
# 40         SDS  VLOOKUP($A102,G:\EO2018\FrozenResults\Demand\_...
# 42         SDS  VLOOKUP($A104,G:\EO2018\FrozenResults\Demand\_...
# 43         SDS  VLOOKUP($A105,G:\EO2018\FrozenResults\Demand\_...
# 53        Hist  HLOOKUP($B278,G:\EO2018\FrozenResults\Demand\A...
# 54        Hist  HLOOKUP($B279,G:\EO2018\FrozenResults\Demand\A...
# 55        Hist  HLOOKUP($B280,G:\EO2018\FrozenResults\Demand\A...
# 56        Hist  HLOOKUP($B281,G:\EO2018\FrozenResults\Demand\A...
# 57        Hist  HLOOKUP($B282,G:\EO2018\FrozenResults\Demand\A...
# 58        Hist  HLOOKUP($B283,G:\EO2018\FrozenResults\Demand\A...
# 59         NPS  HLOOKUP($B284,G:\EO2018\FrozenResults\Demand\A...
# 60         NPS  HLOOKUP($B285,G:\EO2018\FrozenResults\Demand\A...
# 64         NPS  HLOOKUP($B321,G:\EO2018\FrozenResults\Demand\A...
# 72    Historic  VLOOKUP($A352,G:\EO2018\FrozenResults\Demand\_...
# 73    Historic  VLOOKUP($A353,G:\EO2018\FrozenResults\Demand\_...
# 74    Historic  VLOOKUP($A354,G:\EO2018\FrozenResults\Demand\_...
# 75    Historic  VLOOKUP($A355,G:\EO2018\FrozenResults\Demand\_...
# 77    Historic  VLOOKUP($A358,G:\EO2018\FrozenResults\Demand\_...
# 78    Historic  VLOOKUP($A359,G:\EO2018\FrozenResults\Demand\_...
# 80    Historic  VLOOKUP($A362,G:\EO2018\FrozenResults\Demand\_...
# 82    Historic  VLOOKUP($A372,G:\EO2018\FrozenResults\Demand\_...
# 83    Historic  VLOOKUP($A373,G:\EO2018\FrozenResults\Demand\_...
# ...        ...                                                ...
# 1648       NaN  HLOOKUP($B241,G:\EO2018\FrozenResults\Pollutan...
# 1650       NaN  HLOOKUP($B246,G:\EO2018\FrozenResults\Pollutan...
# 1651       NaN  HLOOKUP($B247,G:\EO2018\FrozenResults\Pollutan...
# 1652       NaN  HLOOKUP($B248,G:\EO2018\FrozenResults\Pollutan...
# 1666       SDS  VLOOKUP(A6,G:\EO2018\FrozenResults\Demand\_Agg...
# 1667       SDS  VLOOKUP(A7,G:\EO2018\FrozenResults\Demand\_Agg...
# 1669       SDS  VLOOKUP(A9,G:\EO2018\FrozenResults\Demand\_Agg...
# 1670       SDS  VLOOKUP(A10,G:\EO2018\FrozenResults\Demand\_Ag...
# 1671       NPS  VLOOKUP(A11,G:\EO2018\FrozenResults\Demand\_Ag...
# 1672       NPS  VLOOKUP(A12,G:\EO2018\FrozenResults\Demand\_Ag...
# 1674       SDS  VLOOKUP(A14,G:\EO2018\FrozenResults\Demand\_Ag...
# 1675       SDS  VLOOKUP(A15,G:\EO2018\FrozenResults\Demand\_Ag...
# 1676       NPS  VLOOKUP(A16,G:\EO2018\FrozenResults\Demand\_Ag...
# 1677       NPS  VLOOKUP(A17,G:\EO2018\FrozenResults\Demand\_Ag...
# 1679       SDS  VLOOKUP(A22,G:\EO2018\FrozenResults\Demand\_Ag...
# 1680       SDS  VLOOKUP(A23,G:\EO2018\FrozenResults\Demand\_Ag...
# 1681       SDS  VLOOKUP(A24,G:\EO2018\FrozenResults\Demand\_Ag...
# 1682       SDS  VLOOKUP(A25,G:\EO2018\FrozenResults\Demand\_Ag...
# 1684       SDS  VLOOKUP(A27,G:\EO2018\FrozenResults\Demand\_Ag...
# 1685       SDS  VLOOKUP(A28,G:\EO2018\FrozenResults\Demand\_Ag...
# 1686       SDS  VLOOKUP(A29,G:\EO2018\FrozenResults\Demand\_Ag...
# 1687       SDS  VLOOKUP(A30,G:\EO2018\FrozenResults\Demand\_Ag...
# 1689       SDS  VLOOKUP(A32,G:\EO2018\FrozenResults\Demand\_Ag...
# 1690       SDS  VLOOKUP(A33,G:\EO2018\FrozenResults\Demand\_Ag...
# 1691       SDS  VLOOKUP(A34,G:\EO2018\FrozenResults\Demand\_Ag...
# 1692       SDS  VLOOKUP(A35,G:\EO2018\FrozenResults\Demand\_Ag...
# 1694       SDS  HLOOKUP(B40,G:\EO2018\FrozenResults\Demand\PGO...
# 1695       SDS  HLOOKUP(B41,G:\EO2018\FrozenResults\Demand\PGO...
# 1750      2030  HLOOKUP(C145, G:\EO2018\FrozenResults\Demand\A...
# 1751      2030  HLOOKUP(C146, G:\EO2018\FrozenResults\Demand\A...
#
# [1015 rows x 7 columns]

# %%
# drop duplicates
df_lookup_no_dups = df_lookup.drop_duplicates(subset="Text")

# %%
df_lookup_no_dups
# Out:
#                                                    Text  \
# 18    Energy-related carbon dioxide (CO2) emissions ...
# 32    Stronger policy action leads to substantially ...
# 53    for the first time the number of people withou...
# 64    In sub-Saharan Africa 600 million people are s...
# 72    Energy-related carbon dioxide (CO2) emissions ...
# 82                                                    0
# 91    Substantial reductions in major air pollutant ...
# 99    Energy-related CO2 emissions peak and then dec...
# 110   Given expected strong population growth over t...
# 115   The cheapest way to achieve universal electric...
# 127   The cheapest way for people to gain access to ...
# 139   In the Sustainable Development Scenario, emiss...
# 154   Emissions of NOX, which occur predominantly in...
# 165   Universal access to clean cooking reduces resi...
# 196   In the Sustainable Development Scenario, globa...
# 208   In 2017 CO2 and methane emissions from energy ...
# 215   The largest by some measure is coal-fired powe...
# 223                                         Oil and gas
# 248                                              trucks
# 279   The largest emitter in 2040 becomes cement pro...
# 283   Emissions from cars halve, despite the number ...
# 300   Overall, the proportion of emissions from the ...
# 307   Energy consumption patterns shift driven first...
# 317   Within this more efficient energy system, ther...
# 330   Industry is the only end-use sector to see a s...
# 354   Total energy consumption in the transport sect...
# 394   Improved energy efficiency means energy use in...
# 406   A further marked change is a sharp reduction o...
# 453   Overall primary energy demand stays flat in th...
# 459   The shifts in energy consumption and power gen...
# ...                                                 ...
# 1462  Electricity tariffs were reduced in Thailand, ...
# 1472  China has phased out gas subsidies in the indu...
# 1476  Subsidies have risen slightly in 2017, but by ...
# 1481  Methane emissions from the oil and gas sector ...
# 1487  Over 80% of the emissions come from upstream p...
# 1493  Methane emissions äóñ particularly for upstrea...
# 1509  Implementation of 5 measures at no net economi...
# 1518  Around a third of the additional reductions in...
# 1520  The remaining two-thirds come from going furth...
# 1532  Investment in renewables is by itself the seco...
# 1544  The scenario implies a profound and rapid shif...
# 1558  cement, iron and steel, chemicals and aluminiu...
# 1582  Even assuming that every householdäó»s energy ...
# 1586  LPG use for clean cooking access has a similar...
# 1591  Further, people living in sub-Saharan Africa, ...
# 1594  In the Sustainable Development Scenario, despi...
# 1597  Renewables are the most cost-effective route f...
# 1601  CO2 emissions would be lower in 2040 in sub-Sa...
# 1604  Achieving universal access to modern energy do...
# 1623  In the Sustainable Development Scenario, CO2 e...
# 1629  The transport sector is currently the biggest ...
# 1631  The additional transport NOx reductions in the...
# 1638  By 2040, the majority of additional reductions...
# 1642  ¥¬ for PM2.5 emissions, more than half of cur...
# 1647  The proportion is set to remain almost unchang...
# 1650  In the Sustainable Development Scenario, effor...
# 1666  In the Sustainable Development Scenario, a com...
# 1679  The share of electricity increases substantial...
# 1694  Support  for renewable electricity has led to ...
# 1750  For example, mini-grids äóñ which provide elec...
#
#                          Published value Author calc Value  \
# 18                  increased deployment        723.284262
# 32                  substantially higher       38.27872429
# 53                    for the first time        1422.12966
# 64                    600 million people         580.67282
# 72     for the first time in three years       32138.38726
# 82    increased deployment of renewables        723.284262
# 91                Substantial reductions        48404.7228
# 99                                  peak       34884.22829
# 110                   around 1.2 billion       1218.768702
# 115                             cheapest       375.3342133
# 127                                 most       1342.173675
# 139                      almost constant       72874.18132
# 154                       more than half       26287.11859
# 165                             followed       25426.88067
# 196                           objectives       32580.35787
# 208                                 38.7       34882.05878
# 215                                 2053        2066.73856
# 223                                 0.07       9821.735476
# 248                                  202       144.0901296
# 279                             majority       2050.103031
# 283          increasing by more than 60%       1.139795662
# 300                                  0.2       32580.35787
# 307                    energy efficiency       9695.949122
# 317                                 0.28       9695.949122
# 330                               growth       2855.353287
# 354                          almost flat       2794.331543
# 394                              growing       127795.9227
# 406                               reduce       3047.236939
# 453                               strong       13971.70618
# 459                         nearly eight       13971.70618
# ...                                  ...               ...
# 1462                  reduced - Thailand          4.095342
# 1472                           countered       7179.843072
# 1476                      risen slightly       260206.7395
# 1481                           increased           76.0104
# 1487                            Over 80%           64.3435
# 1493                        particularly           3599.48
# 1509                      less than half       49602.24831
# 1518                      Around a third       43194.48099
# 1520                remaining two-thirds        18913.2492
# 1532                      second biggest       49602.24831
# 1544                             decline       32580.35787
# 1558                                0.17       34884.22829
# 1582                             338 TWh       338.2859882
# 1586                              1 mb/d       0.938418381
# 1591                            13 times       0.669357955
# 1594                                   8       0.369101423
# 1597               around three-quarters       1218.768702
# 1601                               lower       1027.449851
# 1604                   does not increase       0.602952185
# 1623                reduced concurrently        32580.7653
# 1629                             biggest       108025.5295
# 1631                   largely driven by       16.90090588
# 1638                            majority       25888.01966
# 1642                      more than half       17110.14893
# 1647                    almost unchanged       13319.08856
# 1650            almost total elimination       17110.14893
# 1666                           increased       1846.007222
# 1679  increases substantially - industry       945.1539478
# 1694                      rapidly rising       144.9949159
# 1750                                0.45       406.7814666
#
#                 Look-up value                       Look-up year  Scenario  \
# 18                  PGINrenew                               2016  Historic
# 32     InvCosts_IND_Eff_Total                            cum2040       NaN
# 53            PopwoElecAccess                               2010      Hist
# 64            PopwoElecAccess                               2030       NPS
# 72               CO2TPEDtotal                               2014  Historic
# 82                  PGINrenew                               2016  Historic
# 91                  SO2_total                               2030       NPS
# 99          CO2_TPED_IP_total                               2017       SDS
# 110          CumPopElecAccess                               2030       SDS
# 115          AccessPGOUTtotal                               2030       SDS
# 127                AddPop_LPG                               2030       SDS
# 139                 SO2_Total                               2015       NPS
# 154              SO2_PP_Total                               2015       NPS
# 165             PM_Comb_Total                               2015       NPS
# 196              CO2TPEDtotal                               2017       NPS
# 208         CO2_TPED_IP_total                               2017       NPS
# 215                PGCap_coal                               2017       NPS
# 223               CO2PGINcoal                               2017       NPS
# 248      VehicleRoadStock_LCV                               2017       NPS
# 279           CO2ProcessTotal                               2040       SDS
# 283     VehicleRoadStock_PLDV                               2017       NPS
# 300              CO2TPEDtotal                               2017       NPS
# 307                  TFCtotal                               2017       NPS
# 317                  TFCtotal                               2017       NPS
# 330               TOTINDtotal                               2017       NPS
# 354             TOTTRANStotal                               2017       NPS
# 394         Floor Space Total                               2017       SDS
# 406            BUILDINGStotal                               2017       NPS
# 453                 TPEDtotal                               2017       NPS
# 459                 TPEDtotal                               2017       NPS
# ...                       ...                                ...       ...
# 1462        EndPrice_ELEC_Res                               2015       NaN
# 1472    SubsidyElec_Res_China                               2015       NaN
# 1476       SubsidyTotal_World                               2016       NaN
# 1481             CH4_OILandNG                               2015       NaN
# 1487     CH4upstream_OILandNG                               2017       NaN
# 1493                  NG_PROD                               2015       NaN
# 1509      Efficiency - bridge                            cum2040       NaN
# 1518                    Other                            cum2040       NaN
# 1520       Efficiency - extra                            cum2040       NaN
# 1532      Efficiency - bridge                            cum2040       NaN
# 1544             CO2TPEDtotal                               2017       NPS
# 1558        CO2_TPED_IP_total                               2017     World
# 1582         ElecDemandAccess                               2030     World
# 1586      LPGdemandAccess_mbd                               2030     World
# 1591  INDIC_CO2_TPEDpercapita                               2017  SSAfrica
# 1594  INDIC_CO2_TPEDpercapita                               2040  SSAfrica
# 1597    AccessConnectiontotal                               2030     World
# 1601             CO2TPEDtotal                               2040  SSAfrica
# 1604            TPEDpercapita                               2018  SSAfrica
# 1623             CO2TPEDtotal                               2017     World
# 1629                NOX_total                               2015       NaN
# 1631    Low-carbon transition                               2040   NPS-SDS
# 1638            SO2_Ind_Total                               2015       NaN
# 1642            PM_Bldg_Total                               2015       NaN
# 1647            PM_Bldg_Total                               2040       NaN
# 1650            PM_Bldg_Total                               2015       NaN
# 1666                  TFCelec                               2017       SDS
# 1679               TOTINDelec                               2040       SDS
# 1694  CapAddTotal_WindSolarPV                               2017       SDS
# 1750                      NaN  AccessConnection_rural_total_Mini      2030
#
#                                          Fixed_Formulas
# 18    VLOOKUP($A54,G:\EO2018\FrozenResults\Demand\_A...
# 32    VLOOKUP(A94,G:\EO2018\FrozenResults\Investment...
# 53    HLOOKUP($B278,G:\EO2018\FrozenResults\Demand\A...
# 64    HLOOKUP($B321,G:\EO2018\FrozenResults\Demand\A...
# 72    VLOOKUP($A352,G:\EO2018\FrozenResults\Demand\_...
# 82    VLOOKUP($A372,G:\EO2018\FrozenResults\Demand\_...
# 91    HLOOKUP($B26,G:\EO2018\FrozenResults\Pollutant...
# 99    VLOOKUP($A40,G:\EO2018\FrozenResults\Demand\_A...
# 110   HLOOKUP($B11,G:\EO2018\FrozenResults\Demand\Ac...
# 115   HLOOKUP($B21,G:\EO2018\FrozenResults\Demand\Ac...
# 127   HLOOKUP($B37,G:\EO2018\FrozenResults\Demand\Ac...
# 139   HLOOKUP($B18,G:\EO2018\FrozenResults\Pollutant...
# 154   HLOOKUP($B40,G:\EO2018\FrozenResults\Pollutant...
# 165   HLOOKUP($B55,G:\EO2018\FrozenResults\Pollutant...
# 196   VLOOKUP($A8,G:\EO2018\FrozenResults\Demand\_Ag...
# 208   VLOOKUP($A21,G:\EO2018\FrozenResults\Demand\_A...
# 215   VLOOKUP($A31,G:\EO2018\FrozenResults\Demand\_A...
# 223   VLOOKUP($A42,G:\EO2018\FrozenResults\Demand\_A...
# 248   HLOOKUP(B73,G:\EO2018\FrozenResults\Demand\TRA...
# 279   VLOOKUP($A117,G:\EO2018\FrozenResults\Demand\_...
# 283   HLOOKUP(B122,G:\EO2018\FrozenResults\Demand\TR...
# 300   VLOOKUP($A147,G:\EO2018\FrozenResults\Demand\_...
# 307   VLOOKUP($A8,G:\EO2018\FrozenResults\Demand\_Ag...
# 317   VLOOKUP($A20,G:\EO2018\FrozenResults\Demand\_A...
# 330   VLOOKUP($A35,G:\EO2018\FrozenResults\Demand\_A...
# 354   VLOOKUP($A64,G:\EO2018\FrozenResults\Demand\_A...
# 394   HLOOKUP($B117,G:\EO2018\FrozenResults\Demand\B...
# 406   VLOOKUP($A134,G:\EO2018\FrozenResults\Demand\_...
# 453   VLOOKUP($A196,G:\EO2018\FrozenResults\Demand\_...
# 459   VLOOKUP($A204,G:\EO2018\FrozenResults\Demand\_...
# ...                                                 ...
# 1462  VLOOKUP($A402,G:\EO2018\Model\Assumptions\EndU...
# 1472  VLOOKUP($A422,G:\EO2018\Analysis\Subsidies\Fro...
# 1476  VLOOKUP($A429,G:\EO2018\Analysis\Subsidies\Fro...
# 1481  VLOOKUP(A437, G:\EO2018\FrozenResults\Supply\O...
# 1487  VLOOKUP(A445, G:\EO2018\FrozenResults\Supply\O...
# 1493  VLOOKUP(A458, G:\EO2018\FrozenResults\Supply\O...
# 1509  VLOOKUP(A481,'G:\EO2018\Publications\WEO2018\D...
# 1518  VLOOKUP(A498,'G:\EO2018\Publications\WEO2018\D...
# 1520  VLOOKUP(A503,'G:\EO2018\Publications\WEO2018\D...
# 1532  VLOOKUP(A518,'G:\EO2018\Publications\WEO2018\D...
# 1544  VLOOKUP($A539,G:\EO2018\FrozenResults\Demand\_...
# 1558  VLOOKUP(A41,G:\EO2018\FrozenResults\Demand\_Ag...
# 1582  VLOOKUP(A80,G:\EO2018\FrozenResults\Demand\_Ag...
# 1586  VLOOKUP(A86,G:\EO2018\FrozenResults\Demand\_Ag...
# 1591  VLOOKUP(A94,G:\EO2018\FrozenResults\Demand\_Ag...
# 1594  VLOOKUP(A100,G:\EO2018\FrozenResults\Demand\_A...
# 1597  HLOOKUP($B108,G:\EO2018\FrozenResults\Demand\A...
# 1601  VLOOKUP(A118,G:\EO2018\FrozenResults\Demand\_A...
# 1604  VLOOKUP(A125,G:\EO2018\FrozenResults\Demand\_A...
# 1623  VLOOKUP(A164,G:\EO2018\FrozenResults\Demand\_A...
# 1629  HLOOKUP($B183,G:\EO2018\FrozenResults\Pollutan...
# 1631  VLOOKUP(A194,G:\EO2018\Analysis\Pollution\Air ...
# 1638  HLOOKUP($B208,G:\EO2018\FrozenResults\Pollutan...
# 1642  HLOOKUP($B232,G:\EO2018\FrozenResults\Pollutan...
# 1647  HLOOKUP($B240,G:\EO2018\FrozenResults\Pollutan...
# 1650  HLOOKUP($B246,G:\EO2018\FrozenResults\Pollutan...
# 1666  VLOOKUP(A6,G:\EO2018\FrozenResults\Demand\_Agg...
# 1679  VLOOKUP(A22,G:\EO2018\FrozenResults\Demand\_Ag...
# 1694  HLOOKUP(B40,G:\EO2018\FrozenResults\Demand\PGO...
# 1750  HLOOKUP(C145, G:\EO2018\FrozenResults\Demand\A...
#
# [140 rows x 7 columns]

# %%
# Experiment 1
# The features will be the text and the label will be the lookup-value here

# %%
from src.tokenizer.tokenizer_driver import TokenizerDriver
from src.featurizer.feature_extractor import FeatureExtractor

# %%
tok_driver = TokenizerDriver()
featurizer = FeatureExtractor(mode="tfidf")

# %%
claim_sents = list(df_lookup_no_dups["Text"])

# %%
tokenized_sents = tok_driver.tokenize_claims(claim_sents)

# %%
features = featurizer.featurize_claims(tokenized_sents)

# %%
features.shape
# Out:
# (140, 2444)

# %%
labels = list(df_lookup_no_dups["Look-up value"])

# %%
len(labels)
# Out:
# 140

# %%
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.20, random_state=42)

# %%
X_train.shape, len(y_train), X_test.shape, len(y_test)
# Out:
# ((112, 2444), 112, (28, 2444), 28)

# %%
model = LinearSVC()

# %%
model.fit(X_train, y_train)
# Out:
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0)

# %%
final_model = CalibratedClassifierCV(base_estimator=model, cv="prefit")

# %%
final_model.fit(X_train, y_train)
# Out:
# CalibratedClassifierCV(base_estimator=LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0),
#             cv='prefit', method='sigmoid')

# %%
def _linear_scale_confidence(confidences):
    """
    return the ratio of prob according to the sum of top n probabilities for the predicted intents.
    if probs = [p1, p2, p3] then the return probabilities will be scaled as
    [p1/sum(p1,p2,p3), p2/sum(p1,p2,p3), p3/sum(p1,p2,p3)]
    Args:
        confidences: probabilities of intents
    Returns:
        numpy array: the scaled confidences
    """
    s = np.sum(confidences)
    return confidences/s

# %%
def predict_utt_top_n(mod, featurized_utt, n=3):
    """
    predict the top3 intents along with the confidence probability for each one.
    Note that model.classes_ contains the trained labels in alphabetical order. Here, we sort the
    confidences together with the labels, and return the top3 from this sorted order
    Args:
        featurized_utt (str): featurized and tokenized single utterance
    Returns:
        One list of strings and one list of floats
    """
    raw_confidences = mod.predict_proba(featurized_utt)[0]
    # indices of sorted confidences from high to low confidence
    sorted_conf_idx = np.argsort(raw_confidences)[::-1][:n]
    labels = np.take(mod.classes_, sorted_conf_idx)
    confidences = np.take(raw_confidences, sorted_conf_idx)
    scaled_confidences = _linear_scale_confidence(confidences)

    return labels, scaled_confidences

# %%
temp = X_test[0]

# %%
predict_utt_top_n(final_model, temp.reshape(1, -1))
# Out:
# (array(['SubsidyTotal_World', 'CO2TPEDtotal', 'PGINrenew'], dtype='<U32'),
#  array([0.46084942, 0.39177897, 0.14737161]))

# %%
predictions = [predict_utt_top_n(final_model, test.reshape(1, -1), n=5) for test in X_test]

# %%
predictions
# Out:
# [(array(['SubsidyTotal_World', 'CO2TPEDtotal', 'PGINrenew', 'CO2PGINcoal',
#          'CO2_TPED_IP_total'], dtype='<U32'),
#   array([0.37595172, 0.31960543, 0.1202228 , 0.09787882, 0.08634122])),
#  (array(['InvAccess_cookingtotal', 'PGINrenew', 'AccessPGInvInfra_total',
#          'TPEDperGDP', 'PM_Bldg_Total'], dtype='<U32'),
#   array([0.41828627, 0.17121213, 0.16958955, 0.12451565, 0.1163964 ])),
#  (array(['TPEDgas', 'PGINrenew', 'PGCap_coal', 'PGOUTtotal',
#          'PM_Bldg_Total'], dtype='<U32'),
#   array([0.21492098, 0.2047772 , 0.19995913, 0.19163121, 0.18871147])),
#  (array(['PGINrenew', 'PGOUTtotal', 'ElecGenElecOnly_Coal_Subcritical',
#          'INDIC_CO2_Elec_g_per_kWh', 'TPEDperGDP'], dtype='<U32'),
#   array([0.25922123, 0.23523486, 0.1879944 , 0.15986291, 0.1576866 ])),
#  (array(['TFCtotal', 'PGINrenew', 'TPEDperGDP', 'InvCosts_IND_Eff_Total',
#          'TFCelec'], dtype='<U32'),
#   array([0.30423608, 0.26883416, 0.15053009, 0.13955997, 0.1368397 ])),
#  (array(['CO2TPEDtotal', 'PGINrenew', 'TOTTRANStotal', 'NOX_Total',
#          'NOX_total'], dtype='<U32'),
#   array([0.27185057, 0.20464928, 0.18009984, 0.17943603, 0.16396428])),
#  (array(['CO2TPEDtotal', 'PGINrenew', 'CO2_TPED_IP_total', 'NOX_Total',
#          'China'], dtype='<U32'),
#   array([0.72950641, 0.08025217, 0.07166108, 0.05976947, 0.05881087])),
#  (array(['CO2TPEDtotal', 'PGINrenew', 'Pop_Cooking_SharePollutingFuels',
#          'PopwoElecAccess', 'CO2_TPED_IP_total'], dtype='<U32'),
#   array([0.33722968, 0.2525317 , 0.13958869, 0.13753225, 0.13311768])),
#  (array(['PGINrenew', 'CO2TPEDtotal', 'CO2_TPED_IP_total', 'TPEDperGDP',
#          'TFCtotal'], dtype='<U32'),
#   array([0.29047094, 0.28176097, 0.14437635, 0.14282845, 0.14056329])),
#  (array(['SubsidyTotal_World', 'TPEDgas', 'PGINrenew',
#          'SubsidyElec_Res_China', 'ElecGenElecOnly_Coal_Subcritical'],
#         dtype='<U32'),
#   array([0.23676784, 0.21702162, 0.20880041, 0.17030675, 0.16710337])),
#  (array(['CO2PGINcoal', 'CO2TPEDtotal', 'PGINrenew', 'CO2_TPED_IP_total',
#          'NG_PROD'], dtype='<U32'),
#   array([0.33283503, 0.21417193, 0.17751508, 0.14660797, 0.12886998])),
#  (array(['InvAccess_cookingtotal', 'PGINrenew', 'PG_Total',
#          'Solar PV_World', 'CO2TPEDtotal'], dtype='<U32'),
#   array([0.51105773, 0.16193154, 0.11974615, 0.1055597 , 0.10170489])),
#  (array(['CO2TPEDtotal', 'PM_Bldg_Total', 'InvAccess_cookingtotal',
#          'Pop_WoCleanCookingAccess', 'PGINrenew'], dtype='<U32'),
#   array([0.48928571, 0.14781697, 0.1383964 , 0.11230922, 0.1121917 ])),
#  (array(['CO2TPEDtotal', 'PGINrenew', 'CO2_TPED_IP_total', 'PGCap_coal',
#          'PM_Comb_Total'], dtype='<U32'),
#   array([0.27811509, 0.19716366, 0.19360021, 0.17224601, 0.15887503])),
#  (array(['CO2TPEDtotal', 'China', 'PGINrenew', 'Other',
#          'Pop_Cooking_SharePollutingFuels'], dtype='<U32'),
#   array([0.34550087, 0.18651548, 0.17055035, 0.1500111 , 0.1474222 ])),
#  (array(['CO2TPEDtotal', 'SO2_total', 'PGINrenew', 'Other',
#          'AccessConnectiontotal'], dtype='<U32'),
#   array([0.43603082, 0.16717254, 0.15392681, 0.12198358, 0.12088624])),
#  (array(['CO2TPEDtotal', 'SO2_total', 'PGINrenew', 'NG_PROD', 'TPEDtotal'],
#         dtype='<U32'),
#   array([0.47786016, 0.17690918, 0.13737698, 0.1090018 , 0.09885189])),
#  (array(['SO2_total', 'BUILDINGSbiomass_traditional', 'PGINrenew',
#          'CO2TPEDtotal', 'NOX_Total'], dtype='<U32'),
#   array([0.3263365 , 0.21146039, 0.18702023, 0.14966743, 0.12551545])),
#  (array(['CO2TPEDtotal', 'PopwoElecAccess', 'INDIC_CO2_TPEDpercapita',
#          'PM_Bldg_Total', 'TPEDpercapita'], dtype='<U32'),
#   array([0.79817412, 0.06563289, 0.05291004, 0.04175584, 0.04152712])),
#  (array(['CO2TPEDtotal', 'PGINrenew', 'PopwoElecAccess', 'TFCtotal',
#          'ElecRate_National'], dtype='<U32'),
#   array([0.27484826, 0.2498933 , 0.16960893, 0.1533288 , 0.15232071])),
#  (array(['CapAddTotal_Renew', 'CO2TPEDtotal', 'PGINrenew',
#          'CO2_TPED_IP_total', 'CH4upstream_OILandNG'], dtype='<U32'),
#   array([0.26978892, 0.23658007, 0.21269214, 0.14262023, 0.13831864])),
#  (array(['CO2TPEDtotal', 'PGINrenew', 'Efficiency - bridge',
#          'TOTTRANStotal', 'Solar PV_World'], dtype='<U32'),
#   array([0.33922733, 0.26367595, 0.13755908, 0.13253895, 0.12699868])),
#  (array(['ElecRate_National', 'PGINrenew',
#          'Pop_Cooking_SharePollutingFuels', 'PopElecAccess',
#          'CapAddElecOnly_Coal_Subcritical'], dtype='<U32'),
#   array([0.22771667, 0.21376141, 0.19193167, 0.19191811, 0.17467214])),
#  (array(['PGINrenew', 'CO2TPEDtotal', 'TPEDperGDP', 'GDP',
#          'CO2_TPED_IP_total'], dtype='<U32'),
#   array([0.92546614, 0.02086121, 0.0199038 , 0.01824423, 0.01552462])),
#  (array(['Other', 'PGINrenew', 'CO2TPEDtotal', 'SO2_total', 'NG_PROD'],
#         dtype='<U32'),
#   array([0.26320638, 0.22763641, 0.18960156, 0.16556725, 0.1539884 ])),
#  (array(['TFCtotal', 'InvCosts_IND_Eff_Total', 'PGINrenew', 'PM_Bldg_Total',
#          'CO2TPEDtotal'], dtype='<U32'),
#   array([0.31842222, 0.20175206, 0.17933271, 0.17190675, 0.12858626])),
#  (array(['CO2TPEDtotal', 'PGINrenew', 'TFCtotal', 'CO2_TPED_IP_total',
#          'CapAddTotal_Renew'], dtype='<U32'),
#   array([0.59159391, 0.13373166, 0.10423182, 0.0915402 , 0.0789024 ])),
#  (array(['CapAddTotal_Renew', 'Solar PV_World', 'PGINrenew', 'CO2TPEDtotal',
#          'AccessPGOUTtotal'], dtype='<U32'),
#   array([0.22226356, 0.21901173, 0.21248466, 0.18380144, 0.16243861]))]

# %%
len(y_test)
# Out:
# 28

# %%
len(prediction_labels)
# Out:
# 28

# %%
prediction_labels = [pred[0][0] for pred in predictions]

# %%
n_correct = np.sum(y_test == prediction_labels)
accuracy = float(n_correct / len(y_test))

# %%
n_correct
# Out:
# 0

# %%
[x == y for (x, y) in zip(y_test, prediction_labels)]
# Out:
# [True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True]

# %%
num_correct = 0
for test, pred in zip(y_test, predictions):
    topn = pred[0]
    if test in topn:
        num_correct += 1

# %%
num_correct / len(y_test)
# Out:
# 0.25

# %%
len(df_lookup_no_dups.drop_duplicates(subset="Look-up value"))
# Out:
# 87
